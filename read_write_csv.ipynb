# %%
df = spark.read.csv('/Volumes/workspace/default/raw_data')
display(df)

# %%
df = spark.read.option("header",True).csv('/Volumes/workspace/default/raw_data')
display(df)

# %%
df.printSchema()

# %%
df = spark.read.option("inferSchema",True).option("header",True).csv('/Volumes/workspace/default/raw_data')
display(df)

# %%
df.write.mode("overwrite").parquet('/Volumes/workspace/default/raw_data/orders')
display(df)
